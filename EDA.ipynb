# %% [markdown]
# # IMPPORT LIBRARIES

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mydata=pd.read_csv("insurance.csv")

# %%
mydata.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
mydata.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
mydata.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
mydata.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
mydata.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %%
mydata.duplicated().value_counts()
# Out:
# False    1337
# True        1
# Name: count, dtype: int64

# %%
mydata.drop_duplicates(inplace=True)

# %%
mydata.duplicated().value_counts()
# Out:
# False    1337
# Name: count, dtype: int64

# %%
mydata.shape
# Out:
# (1337, 7)

# %%
mydata.boxplot(column=['age','bmi','children','charges'])
plt.title('boxplot of numerical columns')
plt.show()

# %%
x=np.linspace(0,10,100)
y=np.cos(x)
z=np.sin(x)

# %%
xage=np.array([1,8])
ybmi=np.array([3,10])
plt.plot(xage,ybmi,'o')
plt.show()

# %%
xage=np.array([1,2,6,8])
ybmi=np.array([3,8,1,10])
plt.plot(xage,ybmi)
plt.show()

# %%
mydata['age']>30
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1333     True
# 1334    False
# 1335    False
# 1336    False
# 1337     True
# Name: age, Length: 1337, dtype: bool

# %%
mydata[mydata['age']>30]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# ...   ...     ...     ...       ...    ...        ...          ...
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [894 rows x 7 columns]

# %%
mydata.iloc[0:5]
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
mydata[mydata['region']=="southeast"]
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1      18    male  33.77         1     no  southeast   1725.5523
# 2      28    male  33.00         3     no  southeast   4449.4620
# 5      31  female  25.74         0     no  southeast   3756.6216
# 6      46  female  33.44         1     no  southeast   8240.5896
# 11     62  female  26.29         0    yes  southeast  27808.7251
# ...   ...     ...    ...       ...    ...        ...         ...
# 1322   62    male  38.83         0     no  southeast  12981.3457
# 1323   42  female  40.37         2    yes  southeast  43896.3763
# 1327   51    male  30.03         1     no  southeast   9377.9047
# 1330   57  female  25.74         2     no  southeast  12629.1656
# 1335   18  female  36.85         0     no  southeast   1629.8335
#
# [364 rows x 7 columns]

# %%
mydata.dropna(inplace=True)

# %%
#mydata.fillna(mydata.mean(),inplace=True)

# %%
df=mydata.rename(columns={"sex":"Gender", "charges":"Amount paid"})

# %%
print(df.head())
# Out:
#    age  Gender     bmi  children smoker     region  Amount paid
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
 df['age']=df['age'].astype('int')
df['Amount paid']=df['Amount paid'].apply(lambda x:x*1.1)
df['age_category']=df['age'].apply(lambda x:'adult' if x>18 else 'child')

# %%
print(df)
# Out:
#       age  Gender     bmi  children smoker     region   Amount paid  \
# 0      19  female  27.900         0    yes  southwest  18573.416400
# 1      18    male  33.770         1     no  southeast   1898.107530
# 2      28    male  33.000         3     no  southeast   4894.408200
# 3      33    male  22.705         0     no  northwest  24182.917671
# 4      32    male  28.880         0     no  northwest   4253.540720
# ...   ...     ...     ...       ...    ...        ...           ...
# 1333   50    male  30.970         3     no  northwest  11660.603130
# 1334   18  female  31.920         0     no  northeast   2426.578880
# 1335   18  female  36.850         0     no  southeast   1792.816850
# 1336   21  female  25.800         0     no  southwest   2208.739500
# 1337   61  female  29.070         0    yes  northwest  32055.496330
#
#      age_category
# 0           adult
# 1           child
# 2           adult
# 3           adult
# 4           adult
# ...           ...
# ...

# %%
 df['bmi']=df['bmi'].astype('int')
df['Amount paid']=df['Amount paid'].apply(lambda x:x*1.1)
df['children_category']=df['children'].apply(lambda x:'mature' if x>18 else 'not mature')

# %%
nt(df)
# Out:
#       age  Gender  bmi  children smoker     region   Amount paid age_category  \
# 0      19  female   27         0    yes  southwest  22473.833844        adult
# 1      18    male   33         1     no  southeast   2296.710111        child
# 2      28    male   33         3     no  southeast   5922.233922        adult
# 3      33    male   22         0     no  northwest  29261.330382        adult
# 4      32    male   28         0     no  northwest   5146.784271        adult
# ...   ...     ...  ...       ...    ...        ...           ...          ...
# 1333   50    male   30         3     no  northwest  14109.329787        adult
# 1334   18  female   31         0     no  northeast   2936.160445        child
# 1335   18  female   36         0     no  southeast   2169.308389        child
# 1336   21  female   25         0     no  southwest   2672.574795        adult
# 1337   61  female   29         0    yes  northwest  38787.150559        adult
#
#      children_category
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# male      675
# female    662
# Name: count, dtype: int64

# %%
# %matplotlib inline
plt.plot(df['age'], df['Amount paid'])
plt.xlabel('age')
plt.ylabel('Amount paid')
plt.title('Amount paid vs age')
plt.show()

# %%
# %matplotlib inline
plt.scatter(df['age'], df['Amount paid'])
plt.xlabel('age')
plt.ylabel('Amount paid')
plt.title('Amount paid vs age')
plt.show()

# %%
df['region'].value_counts().plot(kind='bar', color="red")
plt.xlabel('region')
plt.ylabel('count')
plt.title('number of insurance Entries per region')
plt.show()

# %%
df['smoker'].value_counts().plot(kind='bar', color="black")
plt.xlabel('smoker')
plt.ylabel('count')
plt.title('number of insurance Entries per smoke')
plt.show()

# %%
df['age_category'].value_counts().plot(kind='bar', color="green")
plt.xlabel('age_category')
plt.ylabel('count')
plt.title('number of insurance Entries per age_category')
plt.show()

# %%
plt.hist(df['Amount paid'], bins=20)
plt.xlabel('Amount paid')
plt.ylabel('count')
plt.title('number of insurance Entries per Amount paid')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize=(10,7))
ax=fig.add_subplot(111,projection='3d')
x=df['age']
y=df['bmi']
z=df['Amount paid']
ax.scatter(x,y,z,c=z, cmap='viridis',marker='o')
ax.set_xlabel('age')
ax.set_label('bmi')
ax.set_zlabel('Amount paid')
ax.set_title("3D scatter plot of age,bmi,and Amount paid")
plt.show()
